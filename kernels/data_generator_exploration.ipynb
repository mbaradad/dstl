# %%
cd src
# Out:
# [Errno 2] No such file or directory: 'src'
# /home/manel/PycharmProjects/dstl/src

# %%
from data.dataset import Dataset
from utils.utils import *

# %%
d = Dataset(subset=1)
[im, masks] = d.generate_one(0)
print im.shape
print masks.shape

# %%
for i in range(len(i)):
  if 0 <= i and i <= 3:
    print "Color Channel"
  plt.figure(i)
  imshow_one_ch(im[i:i+1,:,:])
for i in range(len(masks)):
    print "Mask: " + str(i)
  imshow_one_ch(masks[i:i+1,:,:])

# %%
# Out:
# 20
